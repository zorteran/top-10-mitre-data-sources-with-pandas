# %%
import pandas as pd
import yaml
import requests

# %% [markdown]
# ## Define assumptions

# %%
my_platforms = ['Windows', 'Linux','Network'] # or None
my_techniques = ['T1204', 'T1053', 'T1543', 'T1134' ,'T1112','T1110','T1003', 'T1135', 'T1046'] # or None

# %% [markdown]
# ## Download and load mitre attack datasources mapping

# %%
url = "https://raw.githubusercontent.com/mitre-attack/attack-datasources/main/docs/techniques_to_components_mapping.yaml"
response = requests.get(url)
mapping = yaml.safe_load(response.content)
df = pd.DataFrame(mapping)

# %%
df.head(3)
# Out:
#   technique_id  x_mitre_is_subtechnique                         technique  \
# 0    T1553.006                     True  Code Signing Policy Modification
# 1    T1553.006                     True  Code Signing Policy Modification
# 2    T1553.006                     True  Code Signing Policy Modification
#
#               tactic          platform       data_source  \
# 0  [defense-evasion]  [Windows, macOS]  windows registry
# 1  [defense-evasion]  [Windows, macOS]           command
# 2  [defense-evasion]  [Windows, macOS]           process
#
#                       data_component
# 0  windows registry key modification
# 1                  command execution
# 2                   process creation

# %% [markdown]
# ## So some pandas transformation

# %%
df = df.explode('platform')

# %%
df.groupby(['platform']).size().to_frame('size').sort_values(by=['size'], ascending=False)
# Out:
#                   size
# platform
# Windows           1296
# macOS              917
# Linux              879
# IaaS               213
# Office 365         176
# Containers         132
# Google Workspace   121
# SaaS               112
# Azure AD           100
# PRE                 89
# Network             73

# %%
if my_platforms:
    df = df.where(df["platform"].isin(my_platforms)).dropna()

# %%
if my_techniques:
    df = df.where(df['technique_id'].isin(my_techniques)).dropna()

# %%
df.head(5)
# Out:
#      technique_id x_mitre_is_subtechnique                        technique  \
# 1094        T1543                   False  Create or Modify System Process
# 1094        T1543                   False  Create or Modify System Process
# 1095        T1543                   False  Create or Modify System Process
# 1095        T1543                   False  Create or Modify System Process
# 1096        T1543                   False  Create or Modify System Process
#
#                                    tactic platform data_source  \
# 1094  [persistence, privilege-escalation]  Windows     service
# 1094  [persistence, privilege-escalation]    Linux     service
# 1095  [persistence, privilege-escalation]  Windows     service
# 1095  [persistence, privilege-escalation]    Linux     service
# 1096  [persistence, privilege-escalation]  Windows     process
#
#             data_component
# 1094      service creation
# 1094      service creation
# 1095  service modification
# 1095  service modification
# 1096      process creation

# %%
df_pivoted = pd.pivot_table(df, values="technique_id",index="technique", columns ="data_component", aggfunc='count', fill_value=0)

# %% [markdown]
# ## Results 🤓

# %%
df_pivoted.style.applymap(lambda x: "background-color: red" if x>0 else "background-color: white")
# Out:
# <style type="text/css">
d_row4_col3, #T_3658d_row4_col4, #T_3658d_row4_col15, #T_3658d_row5_col4, #T_3658d_row5_col16, #T_3658d_row5_col18, #T_3658d_row6_col0, #T_3658d_row6_col4, #T_3658d_row6_col7, #T_3658d_row6_col14, #T_3658d_row6_col15, #T_3658d_row6_col16, #T_3658d_row6_col17, #T_3658d_row6_col18, #T_3658d_row6_col25, #T_3658d_row7_col4, #T_3658d_row7_col5, #T_3658d_row7_col8, #T_3658d_row7_col9, #T_3658d_row7_col18, #T_3658d_row7_col20, #T_3658d_row8_col2, #T_3658d_row8_col4, #T_3658d_row8_col5, #T_3658d_row8_col6, #T_3658d_row8_col8, #T_3658d_row8_col10, #T_3658d_row8_col11, #T_3658d_row8_col12, #T_3658d_row8_col13, #T_3658d_row8_col14, #T_3658d_row8_col18 {
#   background-color: red;
# }
# </style>
# <table id="T_3658d_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >data_component</th>
#       <th class="col_heading level0 col0" >active directory object access</th>
#       <th class="col_heading level0 col1" >active directory object modification</th>
#       <th class="col_heading level0 col2" >application log content</th>
#       <th class="col_heading level0 col3" >cloud service enumeration</th>
#       <th class="col_heading level0 col4" >command execution</th>
#       <th class="col_heading level0 col5" >container creation</th>
#       <th class="col_heading level0 col6" >container start</th>
#       <th class="col_heading level0 col7" >file access</th>
#       <th class="col_heading level0 col8" >file creation</th>
#       <th class="col_heading level0 col9" >file modification</th>
#       <th class="col_heading level0 col10" >image creation</th>
#       <th class="col_heading level0 col11" >instance creation</th>
#       <th class="col_heading level0 col12" >instance start</th>
#       <th class="col_heading level0 col13" >network connection creation</th>
#       <th class="col_heading level0 col14" >network traffic content</th>
#       <th class="col_heading level0 col15" >network traffic flow</th>
#       <th class="col_heading level0 col16" >os api execution</th>
#       <th class="col_heading level0 col17" >process access</th>
#       <th class="col_heading level0 col18" >process creation</th>
#       <th class="col_heading level0 col19" >process metadata</th>
#       <th class="col_heading level0 col20" >scheduled job creation</th>
#       <th class="col_heading level0 col21" >service creation</th>
#       <th class="col_heading level0 col22" >service modification</th>
#       <th class="col_heading level0 col23" >user account authentication</th>
#       <th class="col_heading level0 col24" >user account metadata</th>
#       <th class="col_heading level0 col25" >windows registry key access</th>
#       <th class="col_heading level0 col26" >windows registry key creation</th>
#       <th class="col_heading level0 col27" >windows registry key deletion</th>
#       <th class="col_heading level0 col28" >windows registry key modification</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >technique</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th

# %%
df_pivoted.sum(axis=0).to_frame('size').sort_values(by=['size'],ascending=False).head(10)
# Out:
#                                size
# data_component
# command execution                14
# process creation                 12
# os api execution                  8
# file creation                     6
# network traffic content           4
# network traffic flow              4
# application log content           4
# container creation                4
# file modification                 4
# windows registry key creation     3
